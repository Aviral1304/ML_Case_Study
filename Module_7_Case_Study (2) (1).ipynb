# %%
# Importing pandas library to create dataframe 

import pandas as pd

# %%
#creating dataframe for previous_application dataset as pre_df
leads_df = pd.read_csv('D:\Cdac\Module exam\Module 7 exam\Leads.csv')

# %%
# Creating a copy of dataframe
temp=leads_df

# %%
#Head commands return top 5 values
leads_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# this command will return last 10 values
leads_df.tail()
# Out:
#                                Prospect ID  Lead Number  \
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 9235  Landing Page Submission  Direct Traffic          Yes          No
# 9236  Landing Page Submission  Direct Traffic           No          No
# 9237  Landing Page Submission  Direct Traffic          Yes          No
# 9238  Landing Page Submission          Google           No          No
# 9239  Landing Page Submission  Direct Traffic           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# ...

# %%
# This command will return basic informations about app_df columns and their data types
leads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
#Checking number of rows and columns of dataset
leads_df.shape
# Out:
# (9240, 37)

# %%
#this command will give brief description about every columns(total numbers of columns in the dataset) and also returns extra featurs like count,unique,top,..etc
leads_df.describe(include='all')
# Out:
#                                  Prospect ID    Lead Number  \
# count                                   9240    9240.000000
# unique                                  9240            NaN
# top     7927b2df-8bba-4d29-b9a2-b6e0beafe620            NaN
# freq                                       1            NaN
# mean                                     NaN  617188.435606
# std                                      NaN   23405.995698
# min                                      NaN  579533.000000
# 25%                                      NaN  596484.500000
# 50%                                      NaN  615479.000000
# 75%                                      NaN  637387.250000
# max                                      NaN  660737.000000
#
#                     Lead Origin Lead Source Do Not Email Do Not Call  \
# count                      9240        9204         9240        9240
# unique                        5          21            2           2
# ...

# %%
# To count the null values in each column in the dataset
leads_df.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
# This command will return total number of rows present in each columns except null values.
leads_df.count()
# Out:
# Prospect ID                                      9240
# Lead Number                                      9240
# Lead Origin                                      9240
# Lead Source                                      9204
# Do Not Email                                     9240
# Do Not Call                                      9240
# Converted                                        9240
# TotalVisits                                      9103
# Total Time Spent on Website                      9240
# Page Views Per Visit                             9103
# Last Activity                                    9137
# Country                                          6779
# Specialization                                   7802
# How did you hear about X Education               7033
# What is your current occupation                  6550
# What matters most to you in choosing a course    6531
# Search                                           9240
# ...

# %%
# this command will return all the column name of the respective dataset
leads_df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
# This command return the dimension of the dataframe
leads_df.ndim
# Out:
# 2

# %%
#Checking the columns which have null values in percentage
(leads_df.isnull().sum()/len(leads_df))*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
#Cleaning the missing data
# listing the null values columns having more than 40% null data
leads_df=leads_df.drop(['Lead Quality','Asymmetrique Activity Index','Asymmetrique Profile Index','Asymmetrique Activity Score','Asymmetrique Profile Score'],axis=1)
leads_df.shape
# Out:
# (9240, 32)

# %%
# This command returns the correlation between the columns
leads_df.corr()
# Out:
#                              Lead Number  Converted  TotalVisits  \
# Lead Number                     1.000000   0.025157     0.022223
# Converted                       0.025157   1.000000     0.030395
# TotalVisits                     0.022223   0.030395     1.000000
# Total Time Spent on Website     0.020329   0.362483     0.221240
# Page Views Per Visit            0.058808  -0.003328     0.512125
#
#                              Total Time Spent on Website  Page Views Per Visit
# Lead Number                                     0.020329              0.058808
# Converted                                       0.362483             -0.003328
# TotalVisits                                     0.221240              0.512125
# Total Time Spent on Website                     1.000000              0.320361
# Page Views Per Visit                            0.320361              1.000000

# %%
leads_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
#Finding count of duplicate value
leads_df.duplicated().sum()
# Out:
# 0

# %%
#Chechking the value and their count in city columns
leads_df['City'].value_counts()
# Out:
# Mumbai                         3222
# Select                         2249
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: City, dtype: int64

# %%
# Converting categorical data which have Select value to null value as it doesn't have any significant
import numpy as np
import matplotlib.pyplot as plt
leads_df = leads_df.replace('Select', np.nan)

# %%
#Checking the columns which have null values in percentage
(leads_df.isnull().sum()/len(leads_df))*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   36.580087
# How did you hear about X Education               78.463203
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
#Dropping columns which have null value more than 40
leads_df=leads_df.drop(['How did you hear about X Education','Lead Profile'],axis=1)

# %%
leads_df.shape
# Out:
# (9240, 30)

# %%
#Checking the columns which have null values in percentage
(leads_df.isnull().sum()/len(leads_df))*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   36.580087
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# Search                                            0.000000
# ...

# %%
leads_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
#Dropping columns which are not relevent for model building
leads_df=leads_df.drop(['Prospect ID','Lead Number','Get updates on DM Content','I agree to pay the amount through cheque','A free copy of Mastering The Interview','Last Notable Activity'],axis=1)

# %%
#Checking the no. of rows and columns
leads_df.shape
# Out:
# (9240, 24)

# %%
#Description of dataframe
leads_df.describe(include='all')
# Out:
#                     Lead Origin Lead Source Do Not Email Do Not Call  \
# count                      9240        9204         9240        9240
# unique                        5          21            2           2
# top     Landing Page Submission      Google           No          No
# freq                       4886        2868         8506        9238
# mean                        NaN         NaN          NaN         NaN
# std                         NaN         NaN          NaN         NaN
# min                         NaN         NaN          NaN         NaN
# 25%                         NaN         NaN          NaN         NaN
# 50%                         NaN         NaN          NaN         NaN
# 75%                         NaN         NaN          NaN         NaN
# max                         NaN         NaN          NaN         NaN
#
#           Converted  TotalVisits  Total Time Spent on Website  \
# count   9240.000000  9103.000000                  9240.000000
# ...

# %%
# Handling null values in the data

# %%
#Column name of dataframe
leads_df.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#        'Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Last Activity', 'Country', 'Specialization',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags',
#        'Update me on Supply Chain Content', 'City'],
#       dtype='object')

# %%
#basic information about data types of each columns and the no. of rows
leads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 24 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    9240 non-null   object
#  1   Lead Source                                    9204 non-null   object
#  2   Do Not Email                                   9240 non-null   object
#  3   Do Not Call                                    9240 non-null   object
#  4   Converted                                      9240 non-null   int64
#  5   TotalVisits                                    9103 non-null   float64
#  6   Total Time Spent on Website                    9240 non-null   int64
#  7   Page Views Per Visit                           9103 non-null   float64
#  8   Last Activity                                  9137 non-null   object
# ...

# %%
#Replacing the null values in Totalvisits column with median value
values=leads_df['TotalVisits'].median() 
leads_df.loc[leads_df['TotalVisits'].isnull(),'TotalVisits']=values

# %%
#Counting null values 
leads_df['TotalVisits'].isna().sum()
# Out:
# 0

# %%
#Replacing the null values in Page Views Per Visitcolumn with median value
values=leads_df['Page Views Per Visit'].median()
leads_df.loc[leads_df['Page Views Per Visit'].isnull(),'Page Views Per Visit']=values
leads_df['Page Views Per Visit']
# Out:
# 0       0.00
# 1       2.50
# 2       2.00
# 3       1.00
# 4       1.00
#         ...
# 9235    2.67
# 9236    2.00
# 9237    2.00
# 9238    3.00
# 9239    3.00
# Name: Page Views Per Visit, Length: 9240, dtype: float64

# %%
# Rechecking the column 
leads_df['Page Views Per Visit'].isna().sum()
# Out:
# 0

# %%
#Checking value of Last Activity columns
leads_df['Last Activity'].value_counts()
# Out:
# Email Opened                    3437
# SMS Sent                        2745
# Olark Chat Conversation          973
# Page Visited on Website          640
# Converted to Lead                428
# Email Bounced                    326
# Email Link Clicked               267
# Form Submitted on Website        116
# Unreachable                       93
# Unsubscribed                      61
# Had a Phone Conversation          30
# Approached upfront                 9
# View in browser link Clicked       6
# Email Received                     2
# Email Marked Spam                  2
# Visited Booth in Tradeshow         1
# Resubscribed to emails             1
# Name: Last Activity, dtype: int64

# %%
#Counting null values 
leads_df['Last Activity'].isna().sum()
# Out:
# 103

# %%
# As Email opened data occur more frequently we can replce null values with it
leads_df['Last Activity'] = leads_df['Last Activity'].replace(np.nan,'Email Opened')

# %%
# Rechecking the column 
leads_df['Last Activity'].isna().sum()
# Out:
# 0

# %%
# Checking null values in country columns
leads_df['Country'].isna().sum()
# Out:
# 2461

# %%
#Checking the value of country column
leads_df['Country'].value_counts()
# Out:
# India                   6492
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Hong Kong                  7
# Bahrain                    7
# Oman                       6
# France                     6
# unknown                    5
# South Africa               4
# Nigeria                    4
# Germany                    4
# Kuwait                     4
# Canada                     4
# Sweden                     3
# China                      2
# Asia/Pacific Region        2
# Uganda                     2
# Bangladesh                 2
# Italy                      2
# Belgium                    2
# Netherlands                2
# Ghana                      2
# Philippines                2
# Russia                     1
# Switzerland                1
# Vietnam                    1
# Denmark                    1
# ...

# %%
# As India data occur more frequently we can replce null values with it
leads_df['Country'] = leads_df['Country'].replace(np.nan,'India')

# %%
# Checking null values in country columns
leads_df['Country'].isna().sum()
# Out:
# 0

# %%
# Checking null values in 'What is your current occupation' columns
leads_df['What is your current occupation'].isna().sum()
# Out:
# 2690

# %%
#Checking the value of the column
leads_df['What is your current occupation'].value_counts()
# Out:
# Unemployed              5600
# Working Professional     706
# Student                  210
# Other                     16
# Housewife                 10
# Businessman                8
# Name: What is your current occupation, dtype: int64

# %%
# As India data occur more frequently we can replce null values with it
leads_df['What is your current occupation'] = leads_df['What is your current occupation'].replace(np.nan,'Unemployed')

# %%
# Checking null values in country columns
leads_df['What matters most to you in choosing a course'].isna().sum()
# Out:
# 2709

# %%
leads_df['What matters most to you in choosing a course'].value_counts()
# Out:
# Better Career Prospects      6528
# Flexibility & Convenience       2
# Other                           1
# Name: What matters most to you in choosing a course, dtype: int64

# %%
# As India data occur more frequently we can replce null values with it
leads_df['What matters most to you in choosing a course'] = leads_df['What matters most to you in choosing a course'].replace(np.nan,'Better Career Prospects')

# %%
# Checking null values in country columns
leads_df['Lead Source'].isna().sum()
# Out:
# 36

# %%
#Checking the value of the column
leads_df['Lead Source'].value_counts()
# Out:
# Google               2868
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# google                  5
# Click2call              4
# Press_Release           2
# Social Media            2
# Live Chat               2
# youtubechannel          1
# testone                 1
# Pay per Click Ads       1
# welearnblog_Home        1
# WeLearn                 1
# blog                    1
# NC_EDM                  1
# Name: Lead Source, dtype: int64

# %%
# As Google data occur more frequently we can replce null values with it
leads_df['Lead Source'] = leads_df['Lead Source'].replace(np.nan,'Google')
leads_df['Lead Source'] = leads_df['Lead Source'].replace('google','Google')

# %%
# Checking null values in country columns
leads_df['Specialization'].isna().sum()
# Out:
# 3380

# %%
#Checking the value of the column
leads_df['Specialization'].value_counts()
# Out:
# Finance Management                   976
# Human Resource Management            848
# Marketing Management                 838
# Operations Management                503
# Business Administration              403
# IT Projects Management               366
# Supply Chain Management              349
# Banking, Investment And Insurance    338
# Travel and Tourism                   203
# Media and Advertising                203
# International Business               178
# Healthcare Management                159
# Hospitality Management               114
# E-COMMERCE                           112
# Retail Management                    100
# Rural and Agribusiness                73
# E-Business                            57
# Services Excellence                   40
# Name: Specialization, dtype: int64

# %%
# As Finance Management data occur more frequently we can replce null values with it
leads_df['Specialization'] = leads_df['Specialization'].replace(np.nan,'Finance Management')

# %%
# Checking null values in country columns
leads_df['Tags'].isna().sum()
# Out:
# 3353

# %%
#Checking the value of the column
leads_df['Tags'].value_counts()
# Out:
# Will revert after reading the email                  2072
# Ringing                                              1203
# Interested in other courses                           513
# Already a student                                     465
# Closed by Horizzon                                    358
# switched off                                          240
# Busy                                                  186
# Lost to EINS                                          175
# Not doing further education                           145
# Interested  in full time MBA                          117
# Graduation in progress                                111
# invalid number                                         83
# Diploma holder (Not Eligible)                          63
# wrong number given                                     47
# opp hangup                                             33
# number not provided                                    27
# ...

# %%
# As 'Will revert after reading the email' data occur more frequently we can replce null values with it
leads_df['Tags'] = leads_df['Tags'].replace(np.nan,'Will revert after reading the email')

# %%
# Checking null values in country columns
leads_df['City'].isna().sum()
# Out:
# 3669

# %%
#Checking the value of the column
leads_df['City'].value_counts()
# Out:
# Mumbai                         3222
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: City, dtype: int64

# %%
# As 'Will revert after reading the email' data occur more frequently we can replce null values with it
leads_df['City'] = leads_df['City'].replace(np.nan,'Mumbai')

# %%
leads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 24 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    9240 non-null   object
#  1   Lead Source                                    9240 non-null   object
#  2   Do Not Email                                   9240 non-null   object
#  3   Do Not Call                                    9240 non-null   object
#  4   Converted                                      9240 non-null   int64
#  5   TotalVisits                                    9240 non-null   float64
#  6   Total Time Spent on Website                    9240 non-null   int64
#  7   Page Views Per Visit                           9240 non-null   float64
#  8   Last Activity                                  9240 non-null   object
# ...

# %%
# Checking data Imbalance
leads_df['Lead Origin'].value_counts()
# Out:
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# Quick Add Form                1
# Name: Lead Origin, dtype: int64

# %%
#Counting each value of the column
leads_df['Lead Source'].value_counts()
# Out:
# Google               2909
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# Click2call              4
# Social Media            2
# Live Chat               2
# Press_Release           2
# Pay per Click Ads       1
# blog                    1
# WeLearn                 1
# welearnblog_Home        1
# youtubechannel          1
# testone                 1
# NC_EDM                  1
# Name: Lead Source, dtype: int64

# %%
#Counting each value of the column
leads_df['Do Not Email'].value_counts()
# Out:
# No     8506
# Yes     734
# Name: Do Not Email, dtype: int64

# %%
#Counting each value of the column
leads_df['Do Not Call'].value_counts()
# Out:
# No     9238
# Yes       2
# Name: Do Not Call, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Do Not Call'],axis=1)

# %%
#Counting each value of the column
leads_df['Last Activity'].value_counts()
# Out:
# Email Opened                    3540
# SMS Sent                        2745
# Olark Chat Conversation          973
# Page Visited on Website          640
# Converted to Lead                428
# Email Bounced                    326
# Email Link Clicked               267
# Form Submitted on Website        116
# Unreachable                       93
# Unsubscribed                      61
# Had a Phone Conversation          30
# Approached upfront                 9
# View in browser link Clicked       6
# Email Received                     2
# Email Marked Spam                  2
# Visited Booth in Tradeshow         1
# Resubscribed to emails             1
# Name: Last Activity, dtype: int64

# %%
 #Counting each value of the column
leads_df['Country'].value_counts()
# Out:
# India                   8953
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Hong Kong                  7
# Bahrain                    7
# Oman                       6
# France                     6
# unknown                    5
# South Africa               4
# Nigeria                    4
# Germany                    4
# Kuwait                     4
# Canada                     4
# Sweden                     3
# China                      2
# Asia/Pacific Region        2
# Uganda                     2
# Bangladesh                 2
# Italy                      2
# Belgium                    2
# Netherlands                2
# Ghana                      2
# Philippines                2
# Russia                     1
# Switzerland                1
# Vietnam                    1
# Denmark                    1
# ...

# %%
 #Counting each value of the column
leads_df['Last Activity'].value_counts()
# Out:
# Email Opened                    3540
# SMS Sent                        2745
# Olark Chat Conversation          973
# Page Visited on Website          640
# Converted to Lead                428
# Email Bounced                    326
# Email Link Clicked               267
# Form Submitted on Website        116
# Unreachable                       93
# Unsubscribed                      61
# Had a Phone Conversation          30
# Approached upfront                 9
# View in browser link Clicked       6
# Email Received                     2
# Email Marked Spam                  2
# Visited Booth in Tradeshow         1
# Resubscribed to emails             1
# Name: Last Activity, dtype: int64

# %%
 #Counting each value of the column
leads_df['What is your current occupation'].value_counts()
# Out:
# Unemployed              8290
# Working Professional     706
# Student                  210
# Other                     16
# Housewife                 10
# Businessman                8
# Name: What is your current occupation, dtype: int64

# %%
 #Counting each value of the column
leads_df['What matters most to you in choosing a course'].value_counts()
# Out:
# Better Career Prospects      9237
# Flexibility & Convenience       2
# Other                           1
# Name: What matters most to you in choosing a course, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['What matters most to you in choosing a course'],axis=1)

# %%
 #Counting each value of the column
leads_df['Search'].value_counts()
# Out:
# No     9226
# Yes      14
# Name: Search, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Search'],axis=1)

# %%
 #Counting each value of the column
leads_df['Magazine'].value_counts()
# Out:
# No    9240
# Name: Magazine, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Magazine'],axis=1)

# %%
#Counting each value of the column
leads_df['Newspaper Article'].value_counts()
# Out:
# No     9238
# Yes       2
# Name: Newspaper Article, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Newspaper Article'],axis=1)

# %%
#Counting each value of the column 
leads_df['X Education Forums'].value_counts()
# Out:
# No     9239
# Yes       1
# Name: X Education Forums, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['X Education Forums'],axis=1)

# %%
leads_df['Newspaper'].value_counts()
# Out:
# No     9239
# Yes       1
# Name: Newspaper, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Newspaper'],axis=1)

# %%
leads_df['Digital Advertisement'].value_counts()
# Out:
# No     9236
# Yes       4
# Name: Digital Advertisement, dtype: int64

# %%
#In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Digital Advertisement'],axis=1)

# %%
leads_df['Through Recommendations'].value_counts()
# Out:
# No     9233
# Yes       7
# Name: Through Recommendations, dtype: int64

# %%
 #In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Through Recommendations'],axis=1)

# %%
#Counting each value of the column
leads_df['Receive More Updates About Our Courses'].value_counts()
# Out:
# No    9240
# Name: Receive More Updates About Our Courses, dtype: int64

# %%
 #In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Receive More Updates About Our Courses'],axis=1)

# %%
#Counting each value of the column
leads_df['Update me on Supply Chain Content'].value_counts()
# Out:
# No    9240
# Name: Update me on Supply Chain Content, dtype: int64

# %%
 #In the above column there is so much data imbalance so we can drop this column
leads_df=leads_df.drop(['Update me on Supply Chain Content'],axis=1)

# %%
leads_df['Country'].value_counts()
# Out:
# India                   8953
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Hong Kong                  7
# Bahrain                    7
# Oman                       6
# France                     6
# unknown                    5
# South Africa               4
# Nigeria                    4
# Germany                    4
# Kuwait                     4
# Canada                     4
# Sweden                     3
# China                      2
# Asia/Pacific Region        2
# Uganda                     2
# Bangladesh                 2
# Italy                      2
# Belgium                    2
# Netherlands                2
# Ghana                      2
# Philippines                2
# Russia                     1
# Switzerland                1
# Vietnam                    1
# Denmark                    1
# ...

# %%
leads_df['Specialization'].value_counts()
# Out:
# Finance Management                   4356
# Human Resource Management             848
# Marketing Management                  838
# Operations Management                 503
# Business Administration               403
# IT Projects Management                366
# Supply Chain Management               349
# Banking, Investment And Insurance     338
# Media and Advertising                 203
# Travel and Tourism                    203
# International Business                178
# Healthcare Management                 159
# Hospitality Management                114
# E-COMMERCE                            112
# Retail Management                     100
# Rural and Agribusiness                 73
# E-Business                             57
# Services Excellence                    40
# Name: Specialization, dtype: int64

# %%
leads_df['Tags'].value_counts()
# Out:
# Will revert after reading the email                  5425
# Ringing                                              1203
# Interested in other courses                           513
# Already a student                                     465
# Closed by Horizzon                                    358
# switched off                                          240
# Busy                                                  186
# Lost to EINS                                          175
# Not doing further education                           145
# Interested  in full time MBA                          117
# Graduation in progress                                111
# invalid number                                         83
# Diploma holder (Not Eligible)                          63
# wrong number given                                     47
# opp hangup                                             33
# number not provided                                    27
# ...

# %%
leads_df['City'].value_counts()
# Out:
# Mumbai                         6891
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: City, dtype: int64

# %%
leads_df.shape
# Out:
# (9240, 13)

# %%
leads_df.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity Country           Specialization  \
# 0  Page Visited on Website   India       Finance Management
# ...

# %%
leads_df.columns=['Lead_Origin', 'Lead_Source', 'Do_Not_Email', 'Converted',
       'TotalVisits', 'Total_Time_Spent_on_Website', 'Page_Views_Per_Visit',
       'Last_Activity', 'Country', 'Specialization',
       'Current_Occupation', 'Tags', 'City']

# %%
# Visualization

# %%
import seaborn as sns

# %%
leads_df.corr()
# Out:
#                              Converted  TotalVisits  \
# Converted                     1.000000     0.029119
# TotalVisits                   0.029119     1.000000
# Total_Time_Spent_on_Website   0.362483     0.217341
# Page_Views_Per_Visit         -0.005068     0.512214
#
#                              Total_Time_Spent_on_Website  Page_Views_Per_Visit
# Converted                                       0.362483             -0.005068
# TotalVisits                                     0.217341              0.512214
# Total_Time_Spent_on_Website                     1.000000              0.314266
# Page_Views_Per_Visit                            0.314266              1.000000

# %%
#Checking correlations of numeric values
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(leads_df.corr(), annot=True)
plt.show()

# %%
#pairplot of the dataframe
sns.pairplot(leads_df)

# %%
#Univariate Analysis

# %%
leads_df.columns
# Out:
# Index(['Lead_Origin', 'Lead_Source', 'Do_Not_Email', 'Converted',
#        'TotalVisits', 'Total_Time_Spent_on_Website', 'Page_Views_Per_Visit',
#        'Last_Activity', 'Country', 'Specialization', 'Current_Occupation',
#        'Tags', 'City'],
#       dtype='object')

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = "Lead_Origin", hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = "Lead_Source", hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Do_Not_Email', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
plt.scatter(leads_df.index,leads_df['TotalVisits'])

# %%
#visualizing spread of variable

plt.figure(figsize=(6,4))
sns.boxplot(y=leads_df['TotalVisits'])
plt.show()

# %%
#Outlier Treatment: Remove top & bottom 1% of the Column Outlier values

Q3 = leads_df.TotalVisits.quantile(0.99)
leads_df = leads_df[(leads_df.TotalVisits <= Q3)]
Q1 = leads_df.TotalVisits.quantile(0.01)
leads_df = leads_df[(leads_df.TotalVisits >= Q1)]
sns.boxplot(y=leads_df['TotalVisits'])
plt.show()

# %%
plt.scatter(leads_df.index,leads_df['Total_Time_Spent_on_Website'])

# %%
plt.hist(leads_df['Total_Time_Spent_on_Website'])
# Out:
# (array([4388., 1498.,  473.,  454.,  682.,  702.,  564.,  290.,   87.,
#           19.]),
#  array([   0. ,  227.2,  454.4,  681.6,  908.8, 1136. , 1363.2, 1590.4,
#         1817.6, 2044.8, 2272. ]),
#  <BarContainer object of 10 artists>)

# %%
#visualizing spread of variable

plt.figure(figsize=(6,4))
sns.boxplot(y=leads_df['Total_Time_Spent_on_Website'])
plt.show()

# %%
plt.scatter(leads_df.index,leads_df['Page_Views_Per_Visit'])

# %%
#visualizing spread of variable

plt.figure(figsize=(6,4))
sns.boxplot(y=leads_df['Page_Views_Per_Visit'])
plt.show()

# %%
#Outlier Treatment: Remove top & bottom 1% of the Column Outlier values

Q3 = leads_df.TotalVisits.quantile(0.99)
leads_df = leads_df[(leads_df.Page_Views_Per_Visit <= Q3)]
Q1 = leads_df.Page_Views_Per_Visit.quantile(0.01)
leads_df = leads_df[(leads_df.Page_Views_Per_Visit >= Q1)]
sns.boxplot(y=leads_df['Page_Views_Per_Visit'])
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Last_Activity', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'TotalVisits', hue = "Current_Occupation", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Country', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Current_Occupation', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#checking Spread of "Total Visits" vs Converted variable
sns.boxplot(y = 'TotalVisits', x = 'Converted', data = leads_df)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Lead_Origin', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#checking Spread of "Total Time Spent on Website" vs Converted variable

sns.boxplot(x=leads_df.Converted, y=leads_df['Total_Time_Spent_on_Website'])
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Country', hue = "Current_Occupation", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'City', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Specialization', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
#visualizing count of Variable 

plt.figure(figsize = (14,5))
ax1=sns.countplot(x = 'Tags', hue = "Converted", data = leads_df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
plt.show()

# %%
leads_df.head()
# Out:
#                Lead_Origin     Lead_Source Do_Not_Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total_Time_Spent_on_Website  Page_Views_Per_Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last_Activity Country           Specialization  \
# 0  Page Visited on Website   India       Finance Management
# ...

# %%
# Model Building 1

# %%
#Separting dependent and independent variable
x=leads_df.drop(['Converted'],axis=1)
y=leads_df['Converted']

# %%
x.columns
# Out:
# Index(['Lead_Origin', 'Lead_Source', 'Do_Not_Email', 'TotalVisits',
#        'Total_Time_Spent_on_Website', 'Page_Views_Per_Visit', 'Last_Activity',
#        'Country', 'Specialization', 'Current_Occupation', 'Tags', 'City'],
#       dtype='object')

# %%
#Categorical to Numerical
from sklearn.preprocessing import LabelEncoder
sm=LabelEncoder()
x['Lead_Origin']=sm.fit_transform(x['Lead_Origin'])
x['Lead_Source']=sm.fit_transform(x['Lead_Source'])
x['Do_Not_Email']=sm.fit_transform(x['Do_Not_Email'])
x['TotalVisits']=sm.fit_transform(x['TotalVisits'])
x['Total_Time_Spent_on_Website']=sm.fit_transform(x['Total_Time_Spent_on_Website'])
x['Page_Views_Per_Visit']=sm.fit_transform(x['Page_Views_Per_Visit'])
x['Last_Activity']=sm.fit_transform(x['Last_Activity'])
x['Country']=sm.fit_transform(x['Country'])
x['Specialization']=sm.fit_transform(x['Specialization'])
x['Current_Occupation']=sm.fit_transform(x['Current_Occupation'])
x['Tags']=sm.fit_transform(x['Tags'])
x['City']=sm.fit_transform(x['City'])
x
# Out:
#       Lead_Origin  Lead_Source  Do_Not_Email  TotalVisits  \
# 0               0            6             0            0
# 1               0            7             0            5
# 2               1            1             0            2
# 3               1            1             0            1
# 4               1            3             0            2
# ...           ...          ...           ...          ...
# 9235            1            1             1            8
# 9236            1            1             0            2
# 9237            1            1             1            2
# 9238            1            3             0            3
# 9239            1            1             0            6
#
#       Total_Time_Spent_on_Website  Page_Views_Per_Visit  Last_Activity  \
# 0                               0                     0             10
# 1                             642                    37              5
# ...

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.10353136,  0.59124842, -0.29108016, ..., -0.12260101,
#         -1.11673699, -0.50493087],
#        [-1.10353136,  0.92218969, -0.29108016, ..., -0.12260101,
#         -0.1867135 , -0.50493087],
#        [ 0.47016289, -1.06345791, -0.29108016, ..., -2.92434063,
#          0.58830607, -0.50493087],
#        ...,
#        [ 0.47016289, -1.06345791,  3.43547973, ..., -0.12260101,
#          0.8983139 , -0.50493087],
#        [ 0.47016289, -0.40157538, -0.29108016, ..., -0.12260101,
#          0.58830607,  1.79901576],
#        [ 0.47016289, -1.06345791, -0.29108016, ..., -0.12260101,
#          0.58830607,  0.26305134]])

# %%
#Splitting data into training and testing dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Logistic model
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0) #random_state=0 is optional
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#Predicting Value for test data
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[979, 130],
#        [271, 449]], dtype=int64)

# %%
#Accuracy of model
accuracy_score(y_test,y_pred)
# Out:
# 0.7807545106615636

# %%
#Classification report for the model
from sklearn.metrics import classification_report 
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      1109
#            1       0.78      0.62      0.69       720
#
#     accuracy                           0.78      1829
#    macro avg       0.78      0.75      0.76      1829
# weighted avg       0.78      0.78      0.78      1829

# %%
#Model 2
a=leads_df.drop(['Converted'],axis=1)
b=leads_df['Converted']

# %%
leads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9141 entries, 0 to 9239
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Lead_Origin                  9141 non-null   object
#  1   Lead_Source                  9141 non-null   object
#  2   Do_Not_Email                 9141 non-null   object
#  3   Converted                    9141 non-null   int64
#  4   TotalVisits                  9141 non-null   float64
#  5   Total_Time_Spent_on_Website  9141 non-null   int64
#  6   Page_Views_Per_Visit         9141 non-null   float64
#  7   Last_Activity                9141 non-null   object
#  8   Country                      9141 non-null   object
#  9   Specialization               9141 non-null   object
#  10  Current_Occupation           9141 non-null   object
#  11  Tags                         9141 non-null   object
#  12  City                         9141 non-null   object
# ...

# %%
a
# Out:
#                   Lead_Origin     Lead_Source Do_Not_Email  TotalVisits  \
# 0                         API      Olark Chat           No          0.0
# 1                         API  Organic Search           No          5.0
# 2     Landing Page Submission  Direct Traffic           No          2.0
# 3     Landing Page Submission  Direct Traffic           No          1.0
# 4     Landing Page Submission          Google           No          2.0
# ...                       ...             ...          ...          ...
# 9235  Landing Page Submission  Direct Traffic          Yes          8.0
# 9236  Landing Page Submission  Direct Traffic           No          2.0
# 9237  Landing Page Submission  Direct Traffic          Yes          2.0
# 9238  Landing Page Submission          Google           No          3.0
# 9239  Landing Page Submission  Direct Traffic           No          6.0
#
#       Total_Time_Spent_on_Website  Page_Views_Per_Visit  \
# ...

# %%
# Creating dummy variable
a=pd.get_dummies(a)

# %%
a
# Out:
#       TotalVisits  Total_Time_Spent_on_Website  Page_Views_Per_Visit  \
# 0             0.0                            0                  0.00
# 1             5.0                          674                  2.50
# 2             2.0                         1532                  2.00
# 3             1.0                          305                  1.00
# 4             2.0                         1428                  1.00
# ...           ...                          ...                   ...
# 9235          8.0                         1845                  2.67
# 9236          2.0                          238                  2.00
# 9237          2.0                          199                  2.00
# 9238          3.0                          499                  3.00
# 9239          6.0                         1279                  3.00
#
#       Lead_Origin_API  Lead_Origin_Landing Page Submission  \
# 0                   1                                    0
# ...

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
a=sc.fit_transform(a)
a
# Out:
# array([[-1.08618852, -0.88705147, -1.16526844, ..., -0.20596643,
#         -0.29613567, -0.08972339],
#        [ 0.61956486,  0.34451233,  0.0954583 , ..., -0.20596643,
#         -0.29613567, -0.08972339],
#        [-0.40388717,  1.91228938, -0.15668705, ..., -0.20596643,
#         -0.29613567, -0.08972339],
#        ...,
#        [-0.40388717, -0.52342951, -0.15668705, ..., -0.20596643,
#         -0.29613567, -0.08972339],
#        [-0.06273649,  0.02474428,  0.34760364, ...,  4.85516021,
#         -0.29613567, -0.08972339],
#        [ 0.96071554,  1.44999615,  0.34760364, ..., -0.20596643,
#         -0.29613567, -0.08972339]])

# %%
#Dividing data into training and testing data
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(a,b,test_size=0.2,random_state=0)

# %%
# Logistic model
from sklearn.linear_model import LogisticRegression
classifier2=LogisticRegression(random_state=0) #random_state=0 is optional
classifier2.fit(x_train1,y_train1)
# Out:
# LogisticRegression(random_state=0)

# %%
#Predicting value for test data
y_pred1=classifier2.predict(x_test1)
y_pred1
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred1)
cm
# Out:
# array([[1026,   83],
#        [ 123,  597]], dtype=int64)

# %%
#Checking the accuracy
accuracy_score(y_test,y_pred1)
# Out:
# 0.8873701476216512

# %%
#Classification report for the model
from sklearn.metrics import classification_report 
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1109
#            1       0.88      0.83      0.85       720
#
#     accuracy                           0.89      1829
#    macro avg       0.89      0.88      0.88      1829
# weighted avg       0.89      0.89      0.89      1829
